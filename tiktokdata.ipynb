# %% [markdown]
# <a href="https://colab.research.google.com/github/pankovakris/hse_course_basic/blob/main/tiktokdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt


import numpy as np

# %%
df = pd.read_csv('tiktok.csv')
df = pd.DataFrame(df)

# %%
df.describe()
# Out:
#             duration   popularity  ...        tempo  duration_mins
# count    6746.000000  6746.000000  ...  6746.000000    6746.000000
# mean   194428.739253    57.649422  ...   120.525980       3.240479
# std     59208.593470    24.616537  ...    25.597213       0.986810
# min     43426.000000     0.000000  ...    54.367000       0.723767
# 25%    155866.000000    44.000000  ...   100.053000       2.597767
# 50%    186980.000000    64.000000  ...   120.986000       3.116333
# 75%    224284.000000    76.000000  ...   135.001750       3.738067
# max    716206.000000   100.000000  ...   216.053000      11.936767
#
# [8 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'artist_id', 'artist_name', 'album_id',
#        'duration', 'release_date', 'popularity', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'playlist_id',
#        'playlist_name', 'duration_mins', 'genre'],
#       dtype='object')

# %%
df.loc[df.artist_name == 'Mitski']
# Out:
#                     track_id track_name  ... duration_mins    genre
# 6556  6bTn1ovliI0OkjUNkiMBJq     Nobody  ...      3.223817  _TIKTOK
#
# [1 rows x 23 columns]

# %%
list(df.track_name.loc[df.playlist_name == 'tiktok songs that are actually good'])
# Out:
# ['Electric (feat. Khalid)',
#  'Mr Loverman',
#  'Always Forever',
#  'worldstar money (interlude)',
#  'Powerful (feat. Ellie Goulding & Tarrus Riley)',
#  'How - demo',
#  "She's So Nice",
#  'Weather',
#  'Heart Mind',
#  'No Guidance (feat. Drake)',
#  'MONOPOLY (with Victoria Monét)',
#  'When Will I See You Again',
#  'goosebumps',
#  'Ya Digg',
#  'Melody (1983 Club Vinyl Mix)',
#  'Love Galore (feat. Travis Scott)',
#  'Flashing Lights',
#  'Excitement',
#  'white tee',
#  'I Met Sarah in the Bathroom',
#  'More Than A Woman - From "Saturday Night Fever" Soundtrack',
#  'This Side of Paradise',
#  'PICK IT UP (feat. A$AP Rocky)',
#  'Shoota (feat. Lil Uzi Vert)',
#  "Jus' Know",
#  '2 On (feat. ScHoolboy Q)',
#  'Oh Klahoma',
#  'The Loser',
#  '505',
#  'Michelle',
#  'Ghost Town',
#  'Just the Two of Us',
#  'Act Up',
#  "You're Somebody Else",
#  'Feels (feat. Pharrell Williams, Katy Perry & Big Sean)',
#  'Feels (feat. Pharrell Williams, Katy Perry & Big Sean)',
# ...

# %%
df['track_name'].loc[df.playlist_name == 'tiktok songs that are actually good']
# Out:
# 6417                              Electric (feat. Khalid)
# 6418                                          Mr Loverman
# 6419                                       Always Forever
# 6420                          worldstar money (interlude)
# 6421       Powerful (feat. Ellie Goulding & Tarrus Riley)
#                               ...
# 6570             Cupid's Chokehold / Breakfast In America
# 6571                                          Sneaky Link
# 6572                                            The Spins
# 6573    Peace and Love on the Planet Earth (feat. Zach...
# 6574               Beat Box (feat. Young M.A) - Freestyle
# Name: track_name, Length: 158, dtype: object

# %%
df.sort_values(by='popularity', ascending=False)
# Out:
#                     track_id  ...               genre
# 290   67BtfxlNbhBmCDR2L2l8qd  ...        TIKTOK DANCE
# 5038  67BtfxlNbhBmCDR2L2l8qd  ...             _TIKTOK
# 5035  3VqeTFIvhxu3DIe4eZVzGq  ...             _TIKTOK
# 4076  4iJyoBOLtHqaGxP12qzhQI  ...  TIKTOK PHILIPPINES
# 4216  4iJyoBOLtHqaGxP12qzhQI  ...             _TIKTOK
# ...                      ...  ...                 ...
# 3693  4RcttSz7uRL9O2NyuFKaW2  ...  TIKTOK PHILIPPINES
# 3729  5WpfMpbKbBRLhPu5ZoAqkM  ...  TIKTOK PHILIPPINES
# 2939  5hnkbJ7dztkbgBmS1BbWhO  ...          TIKTOK OPM
# 2938  5hnkbJ7dztkbgBmS1BbWhO  ...          TIKTOK OPM
# 1478  2KVBzvl9gmSRe1Dk6UCvk9  ...        TIKTOK DANCE
#
# [6746 rows x 23 columns]

# %%
g = df.popularity.groupby(df.key).count().plot.bar()
